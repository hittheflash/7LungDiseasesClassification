# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
1

# %%
#!mkdir /root/.kaggle
# !echo '{"username":"hitcode","key":"27d84e45ed4942efc789e9d06db47b8f"}' > /root/.kaggle/kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download nih-chest-xrays/data/
# Out:
# ...
# 100% 42.0G/42.0G [14:37<00:00, 71.0MB/s]
# 100% 42.0G/42.0G [14:37<00:00, 51.4MB/s]

# %%
#kaggle datasets download -d nih-chest-xrays/data

# %%
#import time
#time.sleep(750)

# %%
# !kaggle kernels pull kmader/create-pneumonia-dataturks-dataset
# Out:
# ...
# Source code downloaded to /content/create-pneumonia-dataturks-dataset.ipynb

# %%
#/content/data.zip

# %% [markdown]
# # unizp

# %%
from zipfile import ZipFile

# %%
# %cd /content/drive/My Drive/BIO/dataset
# Out:
# /content/drive/My Drive/BIO/dataset

# %%
#zipObj.filelist

# %%
with ZipFile('/content/data.zip', 'r') as zipObj:
    # Get a list of all archived file names from the zip
    listOfFileNames = zipObj.namelist()
    # Iterate over the file names
    #L = ['images_002']
    L = ['images_010']
    #L = ['images_003', 'images_004', 'images_005']
    #L = ['images_006', 'images_007']
    #L = ['images_011', 'images_012']
    for filename in listOfFileNames:
        #print(filename)
        # Check filename endswith csv
        if filename.endswith('.png'):
            folder = filename.split("/")[0]
            #print(filename)
            if folder in L:
                #L.append(folder)
                zipObj.extract(filename)
            # Extract a single file from zip
            #zipObj.extract(fileName, 'temp_csv')
        print(filename)
    #print(L)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# images_012/images/00028897_017.png
# images_012/images/00028897_018.png
# images_012/images/00028897_019.png
# images_012/images/00028897_020.png
# images_012/images/00028898_000.png
# images_012/images/00028899_000.png
# images_012/images/00028899_001.png
# images_012/images/00028899_002.png
# images_012/images/00028900_000.png
# images_012/images/00028901_000.png
# images_012/images/00028901_001.png
# images_012/images/00028902_000.png
# images_012/images/00028902_001.png
# images_012/images/00028902_002.png
# images_012/images/00028902_003.png
# images_012/images/00028902_004.png
# images_012/images/00028902_005.png
# images_012/images/00028902_006.png
# images_012/images/00028902_007.png
# images_012/images/00028902_008.png
# images_012/images/00028903_000.png
# images_012/images/00028903_001.png
# images_012/images/00028903_002.png
# images_012/images/00028903_003.png
# images_012/images/00028903_004.png
# ...

# %%
imgs_1 = glob("images_001/*/*.*")
len(imgs_1)
# Out:
# 4999

# %%
imgs_2 = glob("images_002/*/*.*")
len(imgs_2)
# Out:
# 10000

# %%
from glob import glob
imgs_3 = glob("images_003/*/*.*")
len(imgs_3)
# Out:
# 10000

# %%
imgs_4 = glob("images_004/*/*.*")
len(imgs_4)
# Out:
# 10000

# %%
imgs_5 = glob("images_005/*/*.*")
len(imgs_5)
# Out:
# 10000

# %%
imgs_6 = glob("images_006/*/*.*")
len(imgs_6)
# Out:
# 10000

# %%
imgs_7 = glob("images_007/*/*.*")
len(imgs_7)
# Out:
# 10000

# %%
imgs_8 = glob("images_008/*/*.*")
len(imgs_8)
# Out:
# 10000

# %%
imgs_9 = glob("images_009/*/*.*")
len(imgs_9)
# Out:
# 10000

# %%
imgs_10 = glob("images_010/*/*.*")
len(imgs_10)
# Out:
# 10000

# %%
imgs_11 = glob("images_011/*/*.*")
len(imgs_11)
# Out:
# 10000

# %%
imgs_12 = glob("images_012/*/*.*")
len(imgs_12)
# Out:
# 7121

# %%
LM = imgs_1 + imgs_2 + imgs_3 + imgs_4 + imgs_5 + imgs_6 + imgs_7 + imgs_8 + imgs_9 + imgs_10 + imgs_11 + imgs_12 
len(LM)
# Out:
# 112120

# %%
# %matplotlib inline
import numpy as np # linear algebra
np.random.seed(2018)
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#import glob
from glob import glob 
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns
#from skimage.util.montage import montage2d
from skimage.io import imread
from tqdm import tqdm

# %%
#base_dir = os.path.join('..', 'input') # 'pulmonary-chest-xray-abnormalities'
all_xray_df = pd.read_csv('Data_Entry_2017.csv')
all_xray_df
# Out:
#              Image Index          Finding Labels  ...     y]  Unnamed: 11
# 0       00000001_000.png            Cardiomegaly  ...  0.143          NaN
# 1       00000001_001.png  Cardiomegaly|Emphysema  ...  0.143          NaN
# 2       00000001_002.png   Cardiomegaly|Effusion  ...  0.168          NaN
# 3       00000002_000.png              No Finding  ...  0.171          NaN
# 4       00000003_000.png                  Hernia  ...  0.143          NaN
# ...                  ...                     ...  ...    ...          ...
# 112115  00030801_001.png          Mass|Pneumonia  ...  0.168          NaN
# 112116  00030802_000.png              No Finding  ...  0.168          NaN
# 112117  00030803_000.png              No Finding  ...  0.168          NaN
# 112118  00030804_000.png              No Finding  ...  0.168          NaN
# 112119  00030805_000.png              No Finding  ...  0.171          NaN
#
# [112120 rows x 12 columns]

# %%
all_image_paths = {
    os.path.basename(x): x for x in LM
    }
print('Scans found:', len(all_image_paths), ', Total Headers', all_xray_df.shape[0])
all_xray_df['path'] = all_xray_df['Image Index'].map(all_image_paths.get)
all_xray_df = all_xray_df.drop(columns=['Unnamed: 11'])
all_xray_df
# Out:
# Scans found: 112120 , Total Headers 112120
#              Image Index  ...                                path
# 0       00000001_000.png  ...  images_001/images/00000001_000.png
# 1       00000001_001.png  ...  images_001/images/00000001_001.png
# 2       00000001_002.png  ...  images_001/images/00000001_002.png
# 3       00000002_000.png  ...  images_001/images/00000002_000.png
# 4       00000003_000.png  ...  images_001/images/00000003_000.png
# ...                  ...  ...                                 ...
# 112115  00030801_001.png  ...  images_012/images/00030801_001.png
# 112116  00030802_000.png  ...  images_012/images/00030802_000.png
# 112117  00030803_000.png  ...  images_012/images/00030803_000.png
# 112118  00030804_000.png  ...  images_012/images/00030804_000.png
# 112119  00030805_000.png  ...  images_012/images/00030805_000.png
#
# [112120 rows x 12 columns]

# %%
all_xray_df2 = all_xray_df.dropna()
all_xray_df2
# Out:
#              Image Index  ...                                path
# 0       00000001_000.png  ...  images_001/images/00000001_000.png
# 1       00000001_001.png  ...  images_001/images/00000001_001.png
# 2       00000001_002.png  ...  images_001/images/00000001_002.png
# 3       00000002_000.png  ...  images_001/images/00000002_000.png
# 4       00000003_000.png  ...  images_001/images/00000003_000.png
# ...                  ...  ...                                 ...
# 112115  00030801_001.png  ...  images_012/images/00030801_001.png
# 112116  00030802_000.png  ...  images_012/images/00030802_000.png
# 112117  00030803_000.png  ...  images_012/images/00030803_000.png
# 112118  00030804_000.png  ...  images_012/images/00030804_000.png
# 112119  00030805_000.png  ...  images_012/images/00030805_000.png
#
# [112120 rows x 12 columns]

# %%
with open('/content/drive/My Drive/BIO/test_list.txt', 'r') as f:
    validated_files = [x.strip() for x in f.readlines()]
all_xray_df2['validated'] = all_xray_df2['Image Index'].isin(validated_files)
all_xray_df2['Single Finding'] = all_xray_df2['Finding Labels'].map(lambda x: '|' not in x)
print('Single Finding Scans:', all_xray_df2['Single Finding'].sum())
all_xray_df2
# Out:
# Single Finding Scans: 91324
#              Image Index          Finding Labels  ...  validated  Single Finding
# 0       00000001_000.png            Cardiomegaly  ...      False            True
# 1       00000001_001.png  Cardiomegaly|Emphysema  ...      False           False
# 2       00000001_002.png   Cardiomegaly|Effusion  ...      False           False
# 3       00000002_000.png              No Finding  ...      False            True
# 4       00000003_000.png                  Hernia  ...       True            True
# ...                  ...                     ...  ...        ...             ...
# 112115  00030801_001.png          Mass|Pneumonia  ...      False           False
# 112116  00030802_000.png              No Finding  ...       True            True
# 112117  00030803_000.png              No Finding  ...       True            True
# 112118  00030804_000.png              No Finding  ...       True            True
# ...

# %%
all_xray_df3 = all_xray_df2[all_xray_df2['Single Finding']].groupby(['Finding Labels'])\
    .size().reset_index(name='counts').sort_values('counts', ascending=False)
all_xray_df3
# Out:
#         Finding Labels  counts
# 10          No Finding   60361
# 8         Infiltration    9547
# 0          Atelectasis    4215
# 4             Effusion    3955
# 11              Nodule    2705
# 14        Pneumothorax    2194
# 9                 Mass    2139
# 2        Consolidation    1310
# 12  Pleural_Thickening    1126
# 1         Cardiomegaly    1093
# 5            Emphysema     892
# 6             Fibrosis     727
# 3                Edema     628
# 13           Pneumonia     322
# 7               Hernia     110

# %%
keep_categories = list(all_xray_df3['Finding Labels'])
keep_categories
# Out:
# ['No Finding',
#  'Infiltration',
#  'Atelectasis',
#  'Effusion',
#  'Nodule',
#  'Pneumothorax',
#  'Mass',
#  'Consolidation',
#  'Pleural_Thickening',
#  'Cardiomegaly',
#  'Emphysema',
#  'Fibrosis',
#  'Edema',
#  'Pneumonia',
#  'Hernia']

# %%
sf_validated_df = all_xray_df2[
    all_xray_df2['Single Finding'] & 
    all_xray_df2['validated'] &
    all_xray_df2['Finding Labels'].map(lambda x: x in keep_categories)
]
sf_validated_df
# Out:
#              Image Index Finding Labels  ...  validated  Single Finding
# 4       00000003_000.png         Hernia  ...       True            True
# 5       00000003_001.png         Hernia  ...       True            True
# 6       00000003_002.png         Hernia  ...       True            True
# 8       00000003_004.png         Hernia  ...       True            True
# 9       00000003_005.png         Hernia  ...       True            True
# ...                  ...            ...  ...        ...             ...
# 112113  00030800_000.png     No Finding  ...       True            True
# 112116  00030802_000.png     No Finding  ...       True            True
# 112117  00030803_000.png     No Finding  ...       True            True
# 112118  00030804_000.png     No Finding  ...       True            True
# 112119  00030805_000.png     No Finding  ...       True            True
#
# [17853 rows x 14 columns]

# %%
#import zipfile as zf
#from skimage.io import imread, imsave
#from skimage.transform import resize
from tqdm import tqdm_notebook
all_rows = []
DS_SIZE = 512
GROUP_SIZE = 20
AGE_SPLITS = 5
#with zf.ZipFile('high_res.zip', 'w') as hrz, zf.ZipFile('low_res.zip', 'w') as lrz:
for finding, rows_df in tqdm_notebook(sf_validated_df.groupby('Finding Labels')):
    # only 1 per patient
    clean_rows_df = rows_df.groupby('Patient ID').apply(lambda x: x.sample(1)).reset_index(drop=True)
    # group by age and gender
    clean_rows_df['age_group'] = pd.qcut(
        clean_rows_df['Patient Age'], AGE_SPLITS)
    ag_groups = clean_rows_df.groupby(['age_group', 
                                        'Patient Gender'])
    
    if len(ag_groups)<GROUP_SIZE:
        # for some patients the count is very low
        # and so we cant really stratify
        out_rows = clean_rows_df.sample(GROUP_SIZE)
    else:
        # if we have enough stratify by age and gender
        out_rows = ag_groups.apply(lambda x: 
                                    x.sample(GROUP_SIZE//AGE_SPLITS)).reset_index(drop=True)
    
    print(finding, out_rows.shape[0],'/',clean_rows_df.shape[0], 'cases')
    arc_path = lambda x: os.path.basename(x)
    for _, c_row in out_rows.iterrows():
        #hrz.write(c_row['path'],
        #    arcname = arc_path(c_row['path']),
        #    compress_type = zf.ZIP_STORED)
        
        full_image = imread(c_row['path'])
        rs_img = resize(full_image, (DS_SIZE, DS_SIZE))
        rgb_rs = plt.cm.gray(rs_img)[:, :, :3]
        #imsave('test.png', rgb_rs)
        #lrz.write('test.png',
        #    arcname = arc_path(c_row['path']),
        #    compress_type = zf.ZIP_STORED)
    all_rows += [out_rows]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # Remove the CWD from sys.path while we load stuff.
# ...
# Atelectasis 20 / 376 cases
# Cardiomegaly 20 / 145 cases
# Consolidation 20 / 230 cases
# Edema 20 / 123 cases
# Effusion 20 / 398 cases
# Emphysema 20 / 157 cases
# Fibrosis 20 / 130 cases
# Hernia 20 / 23 cases
# Infiltration 20 / 565 cases
# Mass 20 / 206 cases
# No Finding 20 / 2557 cases
# Nodule 20 / 247 cases
# Pleural_Thickening 20 / 193 cases
# Pneumonia 20 / 69 cases
# Pneumothorax 20 / 262 cases

# %%
dataset_df_tf = pd.concat(all_rows)
dataset_df_tf.to_csv('dataset_overview.csv', index=False)
dataset_df_tf
# Out:
#           Image Index Finding Labels  ...  Single Finding      age_group
# 135  00012515_005.png    Atelectasis  ...            True  (8.999, 36.0]
# 204  00017036_016.png    Atelectasis  ...            True  (8.999, 36.0]
# 98   00009845_033.png    Atelectasis  ...            True   (55.0, 63.0]
# 345  00028285_007.png    Atelectasis  ...            True  (8.999, 36.0]
# 251  00019769_010.png    Atelectasis  ...            True   (36.0, 48.0]
# ..                ...            ...  ...             ...            ...
# 55   00007830_002.png   Pneumothorax  ...            True  (9.999, 31.0]
# 127  00015646_044.png   Pneumothorax  ...            True   (61.8, 85.0]
# 114  00014083_023.png   Pneumothorax  ...            True  (9.999, 31.0]
# 74   00009863_041.png   Pneumothorax  ...            True   (31.0, 45.0]
# 35   00004342_053.png   Pneumothorax  ...            True   (45.0, 52.0]
#
# [300 rows x 15 columns]

# %%
dataset_df_tf.groupby('Finding Labels').size().reset_index(name='counts')
# Out:
#         Finding Labels  counts
# 0          Atelectasis      20
# 1         Cardiomegaly      20
# 2        Consolidation      20
# 3                Edema      20
# 4             Effusion      20
# 5            Emphysema      20
# 6             Fibrosis      20
# 7               Hernia      20
# 8         Infiltration      20
# 9                 Mass      20
# 10          No Finding      20
# 11              Nodule      20
# 12  Pleural_Thickening      20
# 13           Pneumonia      20
# 14        Pneumothorax      20

# %%
','.join(dataset_df_tf.groupby('Finding Labels').size().reset_index(name='counts')['Finding Labels'].values)
# Out:
# 'Atelectasis,Cardiomegaly,Consolidation,Edema,Effusion,Emphysema,Fibrosis,Hernia,Infiltration,Mass,No Finding,Nodule,Pleural_Thickening,Pneumonia,Pneumothorax'

# %%
sns.swarmplot(y='Finding Labels', 
               x = 'Patient Age', 
               hue = 'Patient Gender',
               data = dataset_df_tf)

# %%
sns.swarmplot(y='Finding Labels', 
               x = 'Patient Age', 
               hue = 'View Position',
               data = dataset_df_tf)

# %%
import time 
time.sleep(1080)
